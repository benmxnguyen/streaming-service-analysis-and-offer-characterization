# %% [markdown]
# # Setup

# %%
#dependecies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sts

# %% [markdown]
# ### Importing DFs

# %%
#variables for forloop
df_name_list = ['disney_plus_content_1.csv', 'disney_plus_content_2.csv', 'movies_per_streaming.csv', 'shows_per_streaming.csv']

#importing data
for i in range(len(df_name_list)):
    locals()[f"df_{i}"] = pd.read_csv(f"Resources/{df_name_list[i]}")

# %% [markdown]
# ### Cleaning DF0

# %%
df_0.columns = map(str.title, df_0.columns)
df_0.head()
# Out:
#      Imdb_Id                                       Title  \
# 0  tt0147800                  10 Things I Hate About You
# 1  tt7019028                        101 Dalmatian Street
# 2  tt0115433                              101 Dalmatians
# 3  tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4  tt0211181                              102 Dalmatians
#
#                                                 Plot    Type  Rated   Year  \
# 0  A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...  series    NaN  2018–
# 2  An evil high-fashion designer plots to steal D...   movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...   movie      G   2000
#
#    Released_At           Added_At  Runtime  \
# 0  31 Mar 1999  November 12, 2019   97 min
# 1  25 Mar 2019  February 28, 2020      NaN
# ...

# %% [markdown]
# ### Cleaning DF1

# %%
df_1.columns = map(str.title, df_1.columns)
df_1.head()
# Out:
#   Show_Id     Type                           Title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      Director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 Cast                Country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %% [markdown]
# ### Cleaning DF2

# %%
clean_df_2 = df_2.loc[df_2['Disney+'] == 1].drop(['Unnamed: 0', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], axis = 1)
clean_df_2.head()
# Out:
#         ID                Title  Year  Age    IMDb Rotten Tomatoes  Type  \
# 270    271           White Fang  2018   7+  7.0/10          76/100     0
# 712    713  Muppets Most Wanted  2014   7+  6.4/10          67/100     0
# 1330  1331               Zapped  2014  all  5.2/10          59/100     0
# 1813  1814    The Blue Umbrella  2005  NaN  7.4/10          54/100     0
# 2029  2030             Sky High  2020  NaN  5.6/10          51/100     0
#
#             Directors                                         Genres  \
# 270    Randal Kleiser                                Adventure,Drama
# 712       James Bobin  Adventure,Comedy,Crime,Family,Musical,Mystery
# 1330      Atlee Kumar                                Action,Thriller
# 1813  Vishal Bhardwaj                    Comedy,Drama,Family,Fantasy
# 2029    Mike Mitchell                 Adventure,Comedy,Family,Sci-Fi
#
#                            Country           Language  Runtime
# ...

# %% [markdown]
# ### Cleaning DF3

# %%
clean_df_3 = df_3.loc[df_3['Disney+'] == 1].drop(['Unnamed: 0', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], axis = 1)
clean_df_3.head()
# Out:
#         ID                 Title  Year  Age    IMDb Rotten Tomatoes  Type
# 321    323  Beauty and the Beast  2012   7+  7.0/10          69/100     1
# 833    836              PJ Masks  2015  all  5.5/10          55/100     1
# 920    923                 X-Men  2011  16+  6.9/10          53/100     1
# 1219  1222         Gigantosaurus  2019  all  7.2/10          48/100     1
# 1580  1586      Inspector Gadget  2015  all  4.6/10          40/100     1

# %% [markdown]
# ### Merging DFs

# %%
merged_df_01 = pd.merge(df_0, df_1, on = 'Title', how = 'outer')
merged_df_34 = pd.merge(clean_df_2, clean_df_3, on = 'Title', how = 'outer')
merged_df = pd.merge(merged_df_01, merged_df_34, on = 'Title', how = 'outer')
merged_df.head()
# Out:
#      Imdb_Id                                       Title  \
# 0  tt0147800                  10 Things I Hate About You
# 1  tt7019028                        101 Dalmatian Street
# 2  tt0115433                              101 Dalmatians
# 3  tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4  tt0211181                              102 Dalmatians
#
#                                                 Plot Type_x_x  Rated   Year  \
# 0  A pretty, popular teenager can't go out on a d...    movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...   series    NaN  2018–
# 2  An evil high-fashion designer plots to steal D...    movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...    movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...    movie      G   2000
#
#    Released_At           Added_At Runtime_x  \
# 0  31 Mar 1999  November 12, 2019    97 min
# 1  25 Mar 2019  February 28, 2020       NaN
# ...

# %% [markdown]
# # Major Cleaning

# %%
merged_df.columns
# Type_x_x, Type_y_x, TypeXy, Type yy
# Imdb_Rating, IMDb_x,IMDB_y
# Director_x, Director_y, Directors, 
# Country_x, Country_y, Country, 
# Added_At, Date_Added
# Rated, Rating
# Runtime_x, Duration, Runtimey
# Released_At, Release_year, Yearx, Yeary
# Genre, Listed_In, Genres
# Plot, Description
# Languagex, Languagey
#Rotten Tomatatoes XY

# DROP: Released_At, Imdb_Id, Age_x, Age_y
# Out:
# Index(['Imdb_Id', 'Title', 'Plot', 'Type_x_x', 'Rated', 'Year', 'Released_At',
#        'Added_At', 'Runtime_x', 'Genre', 'Director_x', 'Writer', 'Actors',
#        'Language_x', 'Country_x', 'Awards', 'Metascore', 'Imdb_Rating',
#        'Imdb_Votes', 'Show_Id', 'Type_y_x', 'Director_y', 'Cast', 'Country_y',
#        'Date_Added', 'Release_Year', 'Rating', 'Duration', 'Listed_In',
#        'Description', 'ID_x', 'Year_x', 'Age_x', 'IMDb_x', 'Rotten Tomatoes_x',
#        'Type_x_y', 'Directors', 'Genres', 'Country', 'Language_y', 'Runtime_y',
#        'ID_y', 'Year_y', 'Age_y', 'IMDb_y', 'Rotten Tomatoes_y', 'Type_y_y'],
#       dtype='object')

# %%
merged_df = merged_df.drop(['Released_At', 'Imdb_Id', 'Age_x', 'Age_y'], axis = 1)

# %%
#finds all unique categorical data
merged_df['Type_x_x'].append(merged_df['Type_y_x']).append(merged_df['Type_x_y']).append(merged_df['Type_y_y']).unique()
# Out:
# array(['movie', 'series', nan, 'episode', 'Movie', 'TV Show', 0.0, 1.0],
#       dtype=object)

# %%
merged_df[['Type_x_x', 'Type_y_x', 'Type_x_y', 'Type_y_y']].replace([series])
# Out:
#      Type_x_x Type_y_x  Type_x_y  Type_y_y
# 0       movie    Movie       NaN       1.0
# 1      series  TV Show       NaN       1.0
# 2       movie    Movie       NaN       1.0
# 3       movie      NaN       NaN       NaN
# 4       movie    Movie       0.0       NaN
# ...       ...      ...       ...       ...
# 1876      NaN      NaN       NaN       1.0
# 1877      NaN      NaN       NaN       1.0
# 1878      NaN      NaN       NaN       1.0
# 1879      NaN      NaN       NaN       1.0
# 1880      NaN      NaN       NaN       1.0
#
# [1881 rows x 4 columns]

# %% [markdown]
# # Summary Statistics
# - total # offerings
# - breadth of offering? # of subcategories etc.
# - min/max/mean of duration of
# - seasons
# - then per episode
# - min/max/mean of ...
# - customer rating
# - critical reception

# %% [markdown]
# # BY SUBCATEGORY ()
# - total # offerings
# - breadth of offering? # of subcategories etc.
# - min/max/mean of duration of
# - seasons
# - then per episode
# - min/max/mean of ...
# - customer rating
# - critical reception
